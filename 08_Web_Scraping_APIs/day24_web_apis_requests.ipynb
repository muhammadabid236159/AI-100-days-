# %%
import requests

# %%
url="https://stephen-king-api.onrender.com/api/books"
response = requests.get(url)
if response.status_code == 200:
    print("Request was successful.")
print(response.status_code)
# Out:
# Request was successful.
# 200

# %%
data=response.json()

# %%
import pandas as pd
df=pd.json_normalize(data["data"])
df.head(10)
df.set_index("id", inplace=True)
df
# Out:
#     Year            Title           handle        Publisher  \
# id
# 1   1974           Carrie           carrie        Doubleday
# 2   1975      Salem's Lot      salem-s-lot        Doubleday
# 3   1977      The Shining      the-shining        Doubleday
# 4   1977             Rage             rage     Signet Books
# 5   1978        The Stand        the-stand        Doubleday
# ..   ...              ...              ...              ...
# 60  2018        Elevation        elevation         Scribner
# 61  2019    The Institute    the-institute         Scribner
# 62  2021            Later            later  Hard Case Crime
# 63  2021    Billy Summers    billy-summers         Scribner
# 72  1979  The Roopak Zone  the-roopak-zone     Viking Press
#
#                     ISBN  Pages  \
# id
# 1      978-0-385-08695-0    199
# 2      978-0-385-00751-1    439
# 3      978-0-385-12167-5    447
# 4      978-0-451-07645-8    211
# 5      978-0-385-12168-2    823
# ..                   ...    ...
# 60     978-1-98210-231-9    144
# 61     978-1-98211-056-7    576
# 62     978-1-78909-649-1    256
# 63     978-1-982-17361-6    528
# 72  978-0-670-26069697-5    428
#
#                                                 Notes  \
# id
# 1                                                  []
# 2             [Nominee, World Fantasy Award, 1976[2]]
# 3   [Runner-up (4th place), Locus Award for Best F...
# 4         [Published under pseudonym Richard Bachman]
# 5   [Nominee, World Fantasy Award, 1979, Runner-up...
# ..                                                ...
# 60                                                 []
# 61  [Nominee, British Fantasy Award's August Derle...
# 62                                                 []
# 63                                                 []
# 72  [Runner-up (2nd place), Locus Award for Best F...
#
#                   created_at  \
# id
# 1   2023-11-13T23:48:47.848Z
# 2   2023-11-13T23:48:48.098Z
# 3   2023-11-13T23:48:48.219Z
# 4   2023-11-13T23:48:48.339Z
# 5   2023-11-13T23:48:48.477Z
# ..                       ...
# 60  2023-11-13T23:48:55.291Z
# 61  2023-11-13T23:48:55.457Z
# 62  2023-11-13T23:48:55.579Z
# 63  2023-11-13T23:48:55.753Z
# 72  2026-06-26T18:20:32.285Z
#
#                                              villains
# id
# 1   [{'name': 'Tina Blake', 'url': 'https://stephe...
# 2   [{'name': 'Kurt Barlow', 'url': 'https://steph...
# 3   [{'name': 'Horace M. Derwent', 'url': 'https:/...
# 4                                                  []
# 5   [{'name': 'Donald Merwin Elbert', 'url': 'http...
# ..                                                ...
# 60                                                 []
# 61  [{'name': 'Gladys Hickson', 'url': 'https://st...
# 62                                                 []
# 63                                                 []
# 72                                                 []
#
# [64 rows x 9 columns]

# %%
import requests

url = "https://meowfacts.herokuapp.com/"
response = requests.get(url)

if response.status_code == 200:
    print("Request was successful.")

data = response.json()
print(data["data"])
# Out:
# Request was successful.
# ['In ancient Egypt, when a family cat died, all family members would shave their eyebrows as a sign of mourning.']

# %%
import requests
import pandas as pd

url = "http://universities.hipolabs.com/search?country=Pakistan"
response = requests.get(url)
data = response.json()
df = pd.json_normalize(data)
df = df[["name", "country", "web_pages"]]
df.head(50)
# Out:
#                                                  name   country  \
# 0           Information Technology University, Lahore  Pakistan
# 1                          Abasyn University Peshawar  Pakistan
# 2                        Allama Iqbal Open University  Pakistan
# 3                   Azad Jammu and Kashmir University  Pakistan
# 4                                 Aga Khan University  Pakistan
# 5                  Jamia Al Dirasat Ul Islami Karachi  Pakistan
# 6                                 Al-Khair University  Pakistan
# 7                             Ahmed Medical Institute  Pakistan
# 8                                      Air University  Pakistan
# 9             The University of Agriculture, Peshawar  Pakistan
# 10                                  Bahria University  Pakistan
# 11         Barani Institute of Information Technology  Pakistan
# 12            Barani Institute of Management Sciences  Pakistan
# 13                           Baqai Medical University  Pakistan
# 14  Balochistan University of Engineering and Tech...  Pakistan
# 15  Balochistan University of Information Technolo...  Pakistan
# 16              Bahauddin Zakariya University, Multan  Pakistan
# 17         Capital University of Science & Technology  Pakistan
# 18               College of Business Management (CBM)  Pakistan
# 19         Cecos Univeristy of Information Technology  Pakistan
# 20  COMSATS Institute of Information Technology, A...  Pakistan
# 21  COMSATS Institute of Information Technology, A...  Pakistan
# 22        COMSATS Institute of Information Technology  Pakistan
# 23  COMSATS Institute of Information Technology, L...  Pakistan
# 24   COMSATS Institute of Information Technology, Wah  Pakistan
# 25                     COSMIQ Institute of Technology  Pakistan
# 26             Dadabhoy Institute of Higher Education  Pakistan
# 27       Dawood College of Engineering and Technology  Pakistan
# 28                  Dow University of Health Sciences  Pakistan
# 29  Faisalabad Institute of Textile and Fashion De...  Pakistan
# 30  Federal Urdu University of Arts,Science and Te...  Pakistan
# 31            Shaheed Benazir Bhutto Women University  Pakistan
# 32             Gandhara Institute of Medical Sciences  Pakistan
# 33               Government College University Lahore  Pakistan
# 34           Government College University Faisalabad  Pakistan
# 35                          University of Balochistan  Pakistan
# 36                              Zia-ud-Din University  Pakistan
# 37                                    Gift University  Pakistan
# 38  Ghulam Ishaq Khan Institute of Science & Techn...  Pakistan
# 39         Gangdara Institute Of Science & Technology  Pakistan
# 40                          The Global College Lahore  Pakistan
# 41                                   Gomal University  Pakistan
# 42                               Greenwich University  Pakistan
# 43                Hajvery University Lahore for Women  Pakistan
# 44                                 Hamdard University  Pakistan
# 45                                   Hitec University  Pakistan
# 46                                  Hazara University  Pakistan
# 47         Institute of Business Administration (IBA)  Pakistan
# 48        Institute of Business Administration Sukkur  Pakistan
# 49    Institute of Industrial Electronics Engineering  Pakistan
#
#                            web_pages
# 0              [https://itu.edu.pk/]
# 1        [http://www.abasyn.edu.pk/]
# 2          [http://www.aiou.edu.pk/]
# 3          [http://www.ajku.edu.pk/]
# 4              [http://www.aku.edu/]
# 5     [http://www.aldirasat.edu.pk/]
# 6       [http://www.alkhair.edu.pk/]
# 7           [http://www.ami.edu.pk/]
# 8            [http://www.au.edu.pk/]
# 9           [http://www.aup.edu.pk/]
# 10       [http://www.bahria.edu.pk/]
# 11         [http://www.biit.edu.pk/]
# 12         [http://www.bims.edu.pk/]
# 13           [https://baqai.edu.pk/]
# 14        [http://www.buetk.edu.pk/]
# 15       [http://www.buitms.edu.pk/]
# 16          [http://www.bzu.edu.pk/]
# 17            [https://cust.edu.pk/]
# 18        [https://cbm.iobm.edu.pk/]
# 19        [http://www.cecos.edu.pk/]
# 20     [http://www.ciit-atd.edu.pk/]
# 21  [http://www.ciit-attock.edu.pk/]
# 22         [http://www.ciit.edu.pk/]
# 23   [http://www.ciitlahore.edu.pk/]
# 24     [http://www.ciit-wah.edu.pk/]
# 25       [http://www.cosmiq.edu.pk/]
# 26     [http://www.dadabhoy.edu.pk/]
# 27         [http://www.dcet.edu.pk/]
# 28         [http://www.duhs.edu.pk/]
# 29        [http://www.fitfd.edu.pk/]
# 30       [http://www.fuuast.edu.pk/]
# 31          [http://www.fwu.edu.pk/]
# 32     [http://www.gandhara.edu.pk/]
# 33          [http://www.gcu.edu.pk/]
# 34         [http://www.gcuf.edu.pk/]
# 35          [http://www.uob.edu.pk/]
# 36              [https://zu.edu.pk/]
# 37         [http://www.gift.edu.pk/]
# 38         [http://www.giki.edu.pk/]
# 39         [http://www.gist.edu.pk/]
# 40       [http://www.global.edu.pk/]
# 41           [http://www.gu.edu.pk/]
# 42         [http://www.guic.edu.pk/]
# 43      [http://www.hajvery.edu.pk/]
# 44      [http://www.hamdard.edu.pk/]
# 45     [http://www.hitecuni.edu.pk/]
# 46           [http://www.hu.edu.pk/]
# 47          [http://www.iba.edu.pk/]
# 48      [http://www.iba-suk.edu.pk/]
# 49         [http://www.iiee.edu.pk/]

# %%
API_KEY = "YOUR_API_KEY_HERE"
url=f"https://generativelanguage.googleapis.com/v1beta/{{name=files/*}}?key={API_KEY}"
response = requests.get(url)
if response.status_code == 200:
    print("Request was successful.")
    data = response.json()

print(data)
# Out:
# {'agents': []}

# %%
import requests
import json

API_KEY = "YOUR_NEW_API_KEY_HERE"

url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={API_KEY}"

payload = {
    "contents": [{
        "parts": [{"text": "Tell me 3 facts about Pakistan"}]
    }]
}

response = requests.post(url, json=payload)
data = response.json()
print(data["candidates"][0]["content"]["parts"][0]["text"])
