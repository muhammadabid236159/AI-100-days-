# %%
import requests

# %%
url="https://stephen-king-api.onrender.com/api/books"
response = requests.get(url)
if response.status_code == 200:
    print("Request was successful.")
print(response.status_code)
# Out:
# Request was successful.
# 200

# %%
data=response.json()

# %%
import pandas as pd
df=pd.json_normalize(data["data"])
df.head(10)
df.set_index("id", inplace=True)
df
# Out:
#     Year            Title           handle        Publisher  \
# id
# 1   1974           Carrie           carrie        Doubleday
# 2   1975      Salem's Lot      salem-s-lot        Doubleday
# 3   1977      The Shining      the-shining        Doubleday
# 4   1977             Rage             rage     Signet Books
# 5   1978        The Stand        the-stand        Doubleday
# ..   ...              ...              ...              ...
# 60  2018        Elevation        elevation         Scribner
# 61  2019    The Institute    the-institute         Scribner
# 62  2021            Later            later  Hard Case Crime
# 63  2021    Billy Summers    billy-summers         Scribner
# 72  1979  The Roopak Zone  the-roopak-zone     Viking Press
#
#                     ISBN  Pages  \
# id
# 1      978-0-385-08695-0    199
# 2      978-0-385-00751-1    439
# 3      978-0-385-12167-5    447
# 4      978-0-451-07645-8    211
# 5      978-0-385-12168-2    823
# ..                   ...    ...
# ...

# %%
import requests

url = "https://meowfacts.herokuapp.com/"
response = requests.get(url)

if response.status_code == 200:
    print("Request was successful.")

data = response.json()
print(data.text)
# Out:
# Request was successful.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       6 if response.status_code == 200:
#       7     print("Request was successful.")
#       8
#       9 data = response.json()
# ---> 10 print(data.text)
#
# AttributeError: 'dict' object has no attribute 'text'

# %%
import requests
import pandas as pd

url = "http://universities.hipolabs.com/search?country=Pakistan"
response = requests.get(url)
print(response.text)
# data = response.json()
# df = pd.json_normalize(data)
# df = df[["name", "country", "web_pages"]]

df
# Out:
# [{"state-province": "Punjab", "name": "Information Technology University, Lahore", "web_pages": ["https://itu.edu.pk/"], "alpha_two_code": "PK", "domains": ["itu.edu.pk"], "country": "Pakistan"}, {"state-province": "Khyber Pakhtunkhwa", "name": "Abasyn University Peshawar", "web_pages": ["http://www.abasyn.edu.pk/"], "alpha_two_code": "PK", "domains": ["abasyn.edu.pk"], "country": "Pakistan"}, {"state-province": null, "name": "Allama Iqbal Open University", "web_pages": ["http://www.aiou.edu.pk/"], "alpha_two_code": "PK", "domains": ["aiou.edu.pk"], "country": "Pakistan"}, {"state-province": null, "name": "Azad Jammu and Kashmir University", "web_pages": ["http://www.ajku.edu.pk/"], "alpha_two_code": "PK", "domains": ["ajku.edu.pk"], "country": "Pakistan"}, {"state-province": "Sindh", "name": "Aga Khan University", "web_pages": ["http://www.aku.edu/"], "alpha_two_code": "PK", "domains": ["aku.edu"], "country": "Pakistan"}, {"state-province": "Sindh", "name": "Jamia Al Dirasat Ul Isla
# ...

# %%
API_KEY = "YOUR_API_KEY_HERE"
url=f"https://generativelanguage.googleapis.com/v1beta/{{name=files/*}}?key={API_KEY}"
response = requests.get(url)
if response.status_code == 200:
    print("Request was successful.")
    data = response.json()


print(data.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       5     print("Request was successful.")
#       6     data = response.json()
#       7
#       8
# ----> 9 print(data.text)
#
# AttributeError: 'dict' object has no attribute 'text'

# %%
import requests
import json

API_KEY = "YOUR_NEW_API_KEY_HERE"

url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={API_KEY}"

payload = {
    "contents": [{
        "parts": [{"text": "Tell me 3 facts about Pakistan"}]
    }]
}

response = requests.post(url, json=payload)
data = response.json()
print(data["candidates"][0]["content"]["parts"][0]["text"])
