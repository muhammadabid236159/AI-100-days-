# %% [markdown]
# # 📚 Day 6: Object-Oriented Programming (OOP) - Classes & Objects
#
# ## Topics Covered:
# - Classes and Objects
# - Instance Variables
# - Methods
# - @classmethod decorator
# - @staticmethod decorator
#
# **Confidence Level:** 7/10 | **Time:** 2 hours

# %% [markdown]
# ## Introduction to OOP
#
# Object-Oriented Programming is a way to structure code using classes and objects

# %%
class Car:
    def __init__(self, name, brand):
        self.name = name
        self.brand = brand

    def is_active(self, active):
        self.active = active

    def show(self):
        print(f"Car Name: {self.name}")
        print(f"Brand: {self.brand}")
        print(f"Active: {self.active}")

# Create object
c1 = Car("Prius", "Toyota")
c1.is_active(True)
c1.show()

# %% [markdown]
# ## Class Variables vs Instance Variables
#
# - **Class Variables:** Shared by all instances
# - **Instance Variables:** Unique to each object

# %%
class University:
    department_name = "Computer Science"  # Class variable

    def __init__(self, name, grade, cgpa):
        self.name = name  # Instance variables
        self.grade = grade
        self.cgpa = cgpa
    
    def show_information(self):
        return (University.department_name, self.name, self.grade, self.cgpa)
    
student1 = University("abid", "A", 3.58)
student2 = University("abbas", "B", 3.2)

print(student1.show_information())
print(student2.show_information())

# %% [markdown]
# ## Class Methods & Static Methods
#
# - **@classmethod:** Takes cls parameter (class reference)
# - **@staticmethod:** Independent function in class

# %%
class CompanyLaptop:
    storage = "SSD 256GB"  # Class variable

    def __init__(self, ram, brand):
        self.ram = ram
        self.brand = brand

    def show(self):
        print(f"Brand: {self.brand}, RAM: {self.ram}GB")

    @classmethod
    def show_storage(cls):
        print(f"Storage: {cls.storage}")
    
    @staticmethod
    def calculate_price(price, quantity):
        final_price = price * quantity
        discount = final_price * 10 / 100
        payable = final_price - discount
        return final_price, discount, payable

# Usage
laptop1 = CompanyLaptop(16, "Dell")
laptop1.show()
laptop1.show_storage()
final, discount, payable = laptop1.calculate_price(10000, 5)
print(f"Final: {final}, Discount: {discount}, Payable: {payable}")

# %% [markdown]
# ## Summary
#
# ✅ Created classes with __init__()
# ✅ Used instance methods
# ✅ Understood class vs instance variables
# ✅ Applied @classmethod and @staticmethod
# ✅ Created objects from classes
#
# **Next Step:** Day 7 - Encapsulation & Inheritance
