# %%
# Out:
# hello

# %% [markdown]
# object oerinted progromming

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def show(self):
        print(f"My name is {self.name} and I am {self.age} years old.")

s1=student("abid",19)
s2=student("abbas",23)
s1.show()
s2.show()
# Out:
# My name is abid and I am 19 years old.
# My name is abbas and I am 23 years old.

# %% [markdown]
# types of constructor

# %%
class Car:
    def __init__(self, name, brand):
        self.name = name
        self.brand = brand

    def isactive(self, isactive):
        self.active = isactive

    def show(self):
        print(f"Car Name: {self.name}")
        print(f"Brand: {self.brand}")
        print(f"Active: {self.active}")


c1 = Car("Prius", "Toyota")

c1.isactive(True)   # pehle value save ki
c1.show()           # phir show mein use ki
# Out:
# Car Name: Prius
# Brand: Toyota
# Active: True

# %%
class university:
    depertment_name="Computer Science"

    def __init__(self,name,grade,Cgpa):
        self.name=name
        self.grade=grade
        self.cgpa=Cgpa
    
    def showinformation(self):
        return university.depertment_name,self.name,self.grade,self.cgpa
    
student1=university("abid","A",3.58)
student2=university("abbas","b",3.2)

result=student1.showinformation()
result2=student2.showinformation()

print(result)
print(result2)
# Out:
# ('Computer Science', 'abid', 'A', 3.58)
# ('Computer Science', 'abbas', 'b', 3.2)

# %%
class CompanyLaptop:
    storage = "SSD 256"

    def __init__(self, ram, brand):
        self.ram = ram
        self.brand = brand

    def show(self):
        print(self.brand, self.ram)

    @classmethod
    def show_storage(cls):
        print(cls.storage)
    
    @staticmethod
    def calculate_price(price, quantity):
        final_price = price * quantity
        discount = final_price * 10 / 100
        payable = final_price - discount
        return final_price, discount, payable


laptop1 = CompanyLaptop(256, "Dell")

laptop1.show()
laptop1.show_storage()
finalprice=laptop1.calculate_price(10000,5)
print(finalprice)
# Out:
# Dell 256
# SSD 256
# (50000, 5000.0, 45000.0)
