# %%
import mysql.connector

print("MySQL connector working!")
# Out:
# MySQL connector working!

# %%
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="ai_ml_db"
)
print("canncted")
# Out:
# canncted

# %%
import pandas as pd

query = "SELECT * FROM students"

df = pd.read_sql(query, db)

df
# Out:
# C:\Users\itxab\AppData\Local\Temp\ipykernel_15844\2834720965.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, db)
#    id   name  age  marks        city
# 0   1   Abid   22   85.5        Swat
# 1   2    Ali   21   78.0    Peshawar
# 2   3  Ahmed   23   91.5     Mingora
# 3   4  Usman   22   67.5   Islamabad
# 4   5  Hamza   21   88.0  Rawalpindi
