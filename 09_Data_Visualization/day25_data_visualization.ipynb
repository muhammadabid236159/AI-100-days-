# %% [markdown]
# # 📊 Day 25: Data Visualization
#
# ## Topics Covered:
# - Matplotlib basics
# - Seaborn for statistical visualization
# - Plot types (line, scatter, bar, histogram, pie)
# - Customization and styling
# - Subplots and figure layout
#
# **Confidence Level:** /10 | **Time:** hours

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Matplotlib Basics
